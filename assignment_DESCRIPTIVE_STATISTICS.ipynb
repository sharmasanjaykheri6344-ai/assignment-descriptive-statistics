# %% [markdown]
# Q.1 A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales and why?
#
# ans-...Given data (dozens per day):
#
# [10, 12, 11, 15, 14, 13, 12]
#
# ✅ 1. Mean (Average)
# Mean
# =
# 10
# +
# 12
# +
# 11
# +
# 15
# +
# 14
# +
# 13
# +
# 12
# 7
# Mean=
# 7
# 10+12+11+15+14+13+12
# 	​
#
# =
# 87
# 7
# ≈
# 12.43
# =
# 7
# 87
# 	​
#
# ≈12.43
# ✅ 2. Median (Middle value)
#
# Sort the data:
# [10, 11, 12, 12, 13, 14, 15]
#
# Middle value (4th of 7) = 12
#
# ✅ 3. Mode (Most frequent value)
#
# The only repeated value is 12 → Mode = 12
#
# ⭐ Most representative value: 12 (Median/Mode)
# Why?
#
# The data is fairly symmetrical (no extreme outliers).
#
# 12 appears most often (mode).
#
# Median = 12, which represents the center of the week’s typical daily sales.
#
# The mean is close (12.43), but median/mode better represent the "typical" daily sales because the week shows natural small variations around 12.
#
# Final Answer:
#
# 👉 The most representative value is 12 dozen muffins, because it is both the median and most frequent value, reflecting the typical daily sales for the week.
#
# Q.2 A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
#
# ans.... ✅ Step 1: Calculate the Mean
# Mean
# =
# 12
# +
# 15
# +
# 14
# +
# 16
# +
# 18
# +
# 20
# +
# 19
# 7
# Mean=
# 7
# 12+15+14+16+18+20+19
# 	​
#
# =
# 114
# 7
# ≈
# 16.29
# =
# 7
# 114
# 	​
#
# ≈16.29
# ✔ Mean score ≈ 16.29
# ✅ Step 2: What does the mean tell us?
#
# The average score of 16.29 (out of 20) is quite high.
#
# This suggests that the class performed well overall.
#
# The scores are all reasonably close to each other (no extremely low marks), showing consistent performance across students.
#
# ⭐ Conclusion
#     The mean score of = 16.29 indicates that the class performed strongly , with most students scoring above average and demonstrating a good understanding of the quiz material.
#
#   Q.3 A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager.
#
# ans.... Given shoe sizes:
#
# [7, 8, 9, 8, 8, 10, 7, 9]
#
# ✅ Step 1: Identify the Mode
#
# Count the frequency of each size:
#
# Size 7 → 2 times
#
# Size 8 → 3 times
#
# Size 9 → 2 times
#
# Size 10 → 1 time
#
# ✔ Mode = 8
#
# (Size 8 appears most frequently.)
#
# ✅ Step 2: Why is this useful for the store manager?
#
# Knowing the mode helps the store manager understand:
#
# ⭐ Which shoe size is in highest demand
#
# Size 8 sells the most.
#
# The manager can stock more size 8 shoes to avoid running out.
#
# ⭐ Inventory planning
#
# Helps with purchasing decisions.
#
# Prevents overstock of less popular sizes (e.g., size 10).
#
# ⭐ Improved customer satisfaction
#
# Ensures popular sizes are always available.
#
# Reduces the chance of losing sales.
#
# 📌 Final Answer:
#
# The mode is size 8, and it is useful because it tells the store manager which shoe size is most in demand , helping with better inventory planning and restocking decisions.
#
# Q.4 A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case calculate the mean?
# ...> ✅ Given car prices
#
# [8000, 9500, 10200, 11000, 50000]
#
# ✅ Step 1: Calculate the Mean
# Mean
# =
# 8000
# +
# 9500
# +
# 10200
# +
# 11000
# +
# 50000
# 5
# Mean=
# 5
# 8000+9500+10200+11000+50000
# 	​
#
#
# Sum:
#
# 8000
# +
# 9500
# =
# 17500
# 8000+9500=17500
# 17500
# +
# 10200
# =
# 27700
# 17500+10200=27700
# 27700
# +
# 11000
# =
# 38700
# 27700+11000=38700
# 38700
# +
# 50000
# =
# 88700
# 38700+50000=88700
#
# Now divide:
#
# Mean
# =
# 88700
# 5
# =
# 17
# ,
# 740
# Mean=
# 5
# 88700
# 	​
#
# =17,740
# ✔ Mean price = $17,740
# ✅ Step 2: Calculate the Median
#
# Sorted data:
# [8000, 9500, 10200, 11000, 50000]
#
# Middle value (3rd of 5) → $10,200
#
# ✔ Median price = $10,200
# ⭐ Why is the Median a Better Measure Here?
#
# One value ($50,000) is much higher than the rest.
#
# This extreme outlier pulls the mean upward, making the average look much higher than what most cars actually cost.
#
# Most prices are around $8,000–$11,000, but the mean of $17,740 falsely suggests that cars are much more expensive.
#
# ✔ Median is better because it is not affected by extreme values.
#
# It represents the typical car price more accurately in this dataset.
#
# 📌 Final Answer
#
# Mean price: $17,740
#
# Median price: $10,200 (more representative) because it is not distorted by the $50,000 outlier, giving a clearer picture of normal used-car prices.
#
# Q.5
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the students puzzle solving time?
#
# Given times (in minutes):
#
# [25, 30, 27, 35, 40]
#
# ✅ Step 1: Find the Range
#
# Range = Maximum value – Minimum value
#
# 40
# −
# 25
# =
# 15
# 40−25=15
# ✔ Range = 15 minutes
# Step 2: What does this tell us?
#
# The range of 15 minutes shows that:
#
# The student’s puzzle-solving times vary by up to 15 minutes across the week.
#
# This indicates moderate variation—the times are not perfectly consistent, but they are not extremely scattered either.
#
# It suggests the student may sometimes find the puzzle easier or harder depending on the day.
#
# ⭐ Final Interpretation:
#
# The range of 15 minutes tells us that the students puzzle solving time changes from day to day , showing noticeable but not extreme vaariation in performance.
#
# Q.6 A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. how can this help the farmer his planning in packing?
#
# ...> Given weights (kg):
#
# [100, 105, 98, 110, 120]
#
# ✅ Step 1: Calculate the Range
#
# Range = Maximum – Minimum
#
# 120
# −
# 98
# =
# 22
# 120−98=22
# ✔ Range = 22 kg
# ✅ Step 2: How does this help the farmer in packing?
#
# A range of 22 kg shows that the weekly harvest amount can vary significantly. This helps the farmer in several ways:
#
# ⭐ 1. Packing material planning
#
# Knowing the variation helps estimate how many crates, boxes, or bags are needed.
#
# If some weeks yield much more (e.g., 120 kg), the farmer can ensure extra packing materials are available.
#
# ⭐ 2. Storage space management
#
# The farmer can plan for additional storage in high-yield weeks.
#
# Avoids overcrowding or shortage of space.
#
# ⭐ 3. Transportation planning
#
# Helps decide the size of the vehicle needed.
#
# Prevents underloading or overloading.
#
# ⭐ 4. Predicting supply for markets
#
# With fluctuating quantities, the farmer can forecast how much produce will be available each week.
#
# Ensures better coordination with buyers or market.
#
# Final Answer:
#
# Range = 22 kg
#
# This helps the farmer prepare packing materials, storage, transportation, and market supply planning by understanding how much weekly harvest amounts  can vary.
#
# Q.7 Two delivery companies track delivery delays (in minutes).
#
# Company A: variance = 6
#
# Company B: variance = 15
#  Which  company is more consistent and why?
#
# ..> Company A is more consistent.
# ✔ Why?
#
# Variance measures how spread out the data is from the mean.
#
# A lower variance means the delivery times are more consistent and predictable.
#
# Company A has a variance of 6, which is much lower than Company B's variance of 15.
#
# ⭐ Conclusion:
#
# Company A is more consistent because its delivery delays vary less showing more reliable.
#
# Q.8 A finance student compares the daily price fluctuations of two cryptocurrencies.
#
# Coin A: standard deviation = $30
#
# Coin B: standard deviation = $120
#  Which coin is riskier to invest in, and why?
#
#  ..> Coin B is riskier to invest in.
# ✔ Why?
#
# Standard deviation measures volatility—how much prices fluctuate from day to day.
#
# A higher standard deviation means the price changes are more unpredictable.
#
# Coin B has a standard deviation of $120 which is four times larger than coin A's $ 30 .
#
# conclusion
# coin B is riskier because its price flucates much more , making future values less predictable and increacing investment risk.
#
# Q.9 A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?
#
# ..> Given monthly usage (kWh):
#
# [400, 420, 390, 450, 410]
#
# ✅ Step 1: Mean
# Mean
# =
# 400
# +
# 420
# +
# 390
# +
# 450
# +
# 410
# 5
# Mean=
# 5
# 400+420+390+450+410
# 	​
#
# =
# 2070
# 5
# =
# 414
# =
# 5
# 2070
# 	​
#
# =414
# ✔ Mean = 414 kWh
# ✅ Step 2: Standard Deviation (Population SD)
#
# First find each deviation from the mean and square it:
#
# Value	Deviation	Squared
# 400	-14	196
# 420	6	36
# 390	-24	576
# 450	36	1296
# 410	-4	16
#
# Sum of squared deviations:
#
# 196
# +
# 36
# +
# 576
# +
# 1296
# +
# 16
# =
# 2120
# 196+36+576+1296+16=2120
#
# Population variance:
#
# Variance
# =
# 2120
# 5
# =
# 424
# Variance=
# 5
# 2120
# 	​
#
# =424
#
# Standard deviation:
#
# SD
# =
# 424
# ≈
# 20.59
# SD=
# 424
# 	​
#
# ≈20.59
# ✔ Standard Deviation ≈ 20.6 kWh
# 🔍 Interpretation: What do these values tell us?
# ⭐ Mean = 414 kWh
#
# This is the average monthly usage. It represents the family's typical electricity consumption.
#
# ⭐ Standard deviation ≈ 20.6 kWh
#
# This is small compared to the mean, meaning:
#
# Their electricity usage does not fluctuate much month to month.
#
# The family has stable and consistent energy usage.
#
# No extreme spikes or drops occurred.
#
# 📌 Final Conclusion
#
# mean = 414KWH
# Standard deviation = 20.6KWh
#
# together , these values show that the family uses about 414kwh per month on average , with only small variations indicating steady and predictable electricity consumption.
#
# Q.10 A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?
#
# ..> 1. Mean (Average)
# Mean
# =
# 157
# 8
# =
# 19.625
# Mean=
# 8
# 157
# 	​
#
# =19.625
# ✔ Mean ≈ 19.63 points
# 📌 2. Median (Middle value)
#
# Middle two values: 19 and 20
#
# Median
# =
# 19
# +
# 20
# 2
# =
# 19.5
# Median=
# 2
# 19+20
# 	​
#
# =19.5
# ✔ Median = 19.5 points
# 📌 3. Mode (Most frequent score)
#
# All values appear once → no mode
#
# ✔ Mode = None
# 📌 4. Range
# Range
# =
# 25
# −
# 15
# =
# 10
# Range=25−15=10
# ✔ Range = 10 points
# 📌 5. Standard Deviation (Population SD)
#
# Using mean 19.625, squared deviations sum to ≈ 67.87:
#
# Variance
# =
# 67.87
# 8
# ≈
# 8.48
# Variance=
# 8
# 67.87
# 	​
#
# ≈8.48
# SD
# =
# 8.48
# ≈
# 2.91
# SD=
# 8.48
# 	​
#
# ≈2.91
# ✔ Standard Deviation ≈ 2.91 points
# 🔍 Insights About the Player’s Performance
# ⭐ 1. Consistent scoring
#
# The standard deviation (≈2.9) is small compared to the mean (19.6).
#
# This means the player scores within a narrow range almost every game.
#
# ⭐ 2. Balanced and reliable
#
# Mean (19.63) and median (19.5) are close → no extreme outliers.
#
# Shows stable performance across all games.
#
# ⭐ 3. No particular score dominates
#
# No mode indicates the player does not repeat the same score frequently, showing flexibility in scoring.
#
# ⭐ 4. Moderate variation
#
# Range = 10 points (from 15 to 25).
#
# Shows occasional strong games (25 points) and a few lower ones (15), but still within a reasonable spread.
#
# 🏀 Overall Interpretation
#  the basketball player is a consistent and  dependable scorer , typically scoring around 19-20 points per game with only small varations. this suggest solid stable performance without major flucating.
